# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import gym
import numpy as np
import scipy.signal
import matplotlib.pyplot as plt

# %%
class GymEnvironment:
    def __init__(self, env_id, monitor_dir, max_timesteps=400): #default max_timesteps = 400, testing: 10
        self.max_timesteps = max_timesteps

        self.env = gym.make(env_id)

    def trainPPO(self, agent, no_episodes):
        self.runPPO(agent, no_episodes, training=True)

    def runPPO(self, agent, no_episodes, training=False):

        rew = []
        for episode in range(no_episodes):
            #state = self.env.reset().reshape(1, self.env.observation_space.shape[0])
            states = np.zeros((agent.actors*self.max_timesteps, agent.state_size), dtype = np.float32)
            actions = np.zeros(agent.actors*self.max_timesteps, dtype = np.int32)
            logprobs = np.zeros(agent.actors*self.max_timesteps, dtype = np.float32)
            G_lams = []
            #values_global = []
            storage_counter = 0
            #states, actions, G_lams, values_global, logprobs = [], [], [], [], []

            for n in range(0, agent.actors):
                state = self.env.reset().reshape(1, self.env.observation_space.shape[0])
                # Problem: if done==1, the pole will always fall, so a reset might be good ???
                tot_rew = 0
                values = np.zeros(self.max_timesteps)
                rewards = np.zeros(self.max_timesteps)
                #values, rewards = [], []
                for t in range(self.max_timesteps):
                    # TODO: Fill out the respective to-dos in this loop and make sure that the overall algorithm works,
                    #  e.g., overwrite current state with next state entering a new time step

                    logit, action = agent.select_action(state)
                    next_state, reward, done, _ = self.env.step(action.numpy()[0])

                    next_state = next_state.reshape(1, self.env.observation_space.shape[0])
                    tot_rew += reward

                    states[storage_counter] = state
                    actions[storage_counter] = action

                    """
                    if (done == True) or (t == self.max_timesteps-1):
                        #checking performance:
                        print(f'Episode {episode} actor {n}: reward: {tot_rew} /{self.max_timesteps}')
                    """

                    #print(f'state: {type(state)}, {state}')
                    if training == True:
                        # TODO: Store relevant transition information such as rewards, values, etc. that you will need in
                        #  the calculation of the advantages later
                        rewards[t] = reward
                        #values.append(agent.critic.predict(state)[0])
                        values[t] = agent.critic(state)[0]
                        #print(f'value: {type(agent.critic(state)[0])}, {agent.critic(state)[0]}')
                        logprobs[storage_counter] = policy_probabilities(logit, action)

                    state = next_state
                    storage_counter += 1

                    if ((done == True) or (t == self.max_timesteps-1)) and (training == True):
                        # Calculate advantages when the function breaks or the last iteration is reached
                        # TODO: Call function for calculation and storage of advantages
                        G_lams = np.append(G_lams, agent.calc_advantage(values, rewards, t+1))
                        # TODO: Store targets for your value function update
                        #values_global = np.append(values_global, values)
                        #print(f'rewards: {type(rewards)}, {rewards}')
                        print(f'Episode {episode} actor {n}: reward: {tot_rew} /{self.max_timesteps}')
                        break

                rew.append(tot_rew)

            # TODO: If training, Call function to update value function weights
            #print(f'len_states: {len(states)}')
            #print(f'critic_global: {agent.critic(states)}')
            #print(f'values_global: {type(values_global)}, {len(values_global)} {values_global}')
            #print(f'G_lams: {type(G_lams)}, {len(G_lams)}, {G_lams}')
            #print(f'counter: {storage_counter}')
            #agent.update_value_parameters(G_lams, values_global)
            if training == True:
                G_lams = np.array(G_lams)
                G_lams = G_lams.astype(dtype = np.float32)
                #print(f'G_lams1: {type(G_lams)}, {len(G_lams)}, {G_lams}')
                states = states[0:len(G_lams)]
                actions = actions[0:len(G_lams)]
                logprobs = logprobs[0:len(G_lams)]
                values_global = agent.critic(states)[0]
                advantages = np.subtract(G_lams, values_global)
                #print(f'advantages1: {type(advantages)}, {len(advantages)}, {advantages}')
                #print(f'states: {type(states)}, {len(states)}, {states}')
                # TODO: If training, call function to update policy function weights using clipping
                agent.update_policy_parameters(states,actions,logprobs,G_lams,advantages)
                #print(f'test: {policy_probabilities(agent.actor(states), actions) - logprobs}')
                # TODO: If training, Call function to update value function weights
                agent.update_value_parameters(G_lams, states)
                #agent.update_value_parameters(G_lams,values_global)
                # TODO: Implement here a function that evaulates the agent's performance for every x episodes by
                #  calling PPO directly and returns an average of total rewards for 100 runs, if your objective is
                #  reached, you can terminate training

        print(f'total reward: {sum(rew)} /{self.max_timesteps*agent.actors*no_episodes}')
        return rew

# %%
def policy_probabilities(logit, action):
    # TODO: Compute probabilities of taking actions a by using the outputs of actor NN (the logits)
    # softmax calculation
    #logprobs = tf.math.log(np.exp(logit) / np.sum(np.exp(logit)))
    #print(f'logits: {logit}')
    logprobs = tf.nn.log_softmax(logit)
    #action = tf.dtype.cast(action, dtype = float)
    logprob = tf.reduce_sum(tf.one_hot(action, 2) * logprobs, axis=1)
    #print(f'logprob: {logprob}')
    return logprob


# Sum of discountated rewards of vectors --> useful for advantage estimates or total rewards
def discounted_cumulative_sums(x, discount):
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]

# %%
class PPO_Agent:
    def __init__(self, no_of_states, no_of_actions):
        self.state_size = no_of_states
        self.action_size = no_of_actions

        # TODO: Set hyperparameters and vary them
        self.gamma = 0.9  # discount rate
        self.lam = 0.6  # lambda for TD(lambda)
        self.clip_ratio = 0.5  # Clipping ratio for calculating L_clip
        self.lr = 0.001  # learning rate, default: 0.0001
        self.actors = 10  # Number of parallel actors, default: 100, testing: 10

        self.policy_iterations = 10 # number of policy updates
        self.value_iterations = 10 # number of value updates

        # self.actor = actor()
        # self.critic = critic()
        self.actor = self.nn_model(self.state_size, self.action_size)
        self.actor_optimizer = keras.optimizers.Adam(learning_rate=self.lr)
        self.critic = self.nn_model(self.state_size, 1)
        self.critic_optimizer = keras.optimizers.Adam(learning_rate=self.lr)

    def select_action(self, state):
        # TODO: Implement action selection, i.e., sample an action from policy pi
        # logit = self.actor(np.array([state])).numpy()
        #logit = self.actor(state).numpy()
        logit = agent.actor(state)
        action = tf.squeeze(tf.random.categorical(logit, 1), axis=1)
        return logit, action

    def calc_advantage(self, values, rew, T):
        # TODO: Implement here the calculation of the advantage, e.g., using TD-lambda or eligibility traces
        # Using offline forward-looking TD(lambda) with one update per episode
        G_lam = []
        for t in range(T):
            acc_rew = 0
            rew_list = []
            for k in range(T - t):
                acc_rew = acc_rew + self.gamma ** k * rew[t + k]
                V_tmp = self.gamma ** (k + 1) * values[t + k + 1] if k < T - t - 1 else 0
                rew_list.append((acc_rew + V_tmp) * self.lam ** k)

            G_t = (1 - self.lam) * np.sum(rew_list[:-1]) + rew_list[-1]
            G_lam = np.append(G_lam, G_t)

            """
            G_n = np.zeros(T-t+1)
            for k in range(T-t+1):
                rew_disc = 0
                for i in range(k):
                    rew_disc = rew_disc + rew[t+i] * self.gamma**i
                G_n[k] = rew_disc + values[T+k+1] * self.gamma**(k+1)
            for i in range(t-(T-t)):
                G_n[T-t] = G_n[T-t] + rew[t+i] * self.gamma**i
            G_disc = 0
            for k in range(1, T-t-1):
                G_disc = G_disc + G_n[k-1] * self.lam**(k-1)
            G_lam = (1-self.lam) * G_disc + G_n[T-t] * self.lam**(T-t-1)
            """

            # Consider normalizing the advantages:
            # TD = (TD - np.mean(TD)) / (np.std(TD) + 1e-10)
        #G_lam = tf.convert_to_tensor(G_lam, dtype=float)
        #print(f'G_lam: {type(G_lam)}, {len(G_lam)}, {G_lam}')
        return G_lam

    def nn_model(self, state_size, output_size, ):
        # TODO: Define the neural network here, make sure that you account for the different requirements of the value
        # Define NN architecture
        input_layer = layers.Input(shape = (state_size,))
        layer_1 = layers.Dense(64, activation = "tanh")(input_layer)
        layer_2 = layers.Dense(64, activation = "tanh")(layer_1)
        layer_3 = layers.Dense(64, activation = "tanh")(layer_2)
        layer_4 = layers.Dense(128, activation = "tanh")(layer_3)
        output_layer = layers.Dense(output_size, activation = "tanh")(layer_4)
        model = keras.Model(inputs = input_layer, outputs = output_layer)

        # Compile model
        #model.compile(optimizer = "adam", loss = "mse")

        return model

    # Here newly observed transitions are stored in the experience replay buffer
    def record(self):  # TODO: add the relevant input arguments that you will need to store
        return

    # TODO: Define here arrays in which you will store all the information that you need in the advantage
    #  calculation, e.g., rewards, values, states, etc.

    @tf.function  # This is a wrapper that when adding it in front of a function, consisting only of tf syntax,
    # can improve speed
    def update_policy_parameters(self, states, actions, logprobs, G_lams, advantages):

        for _ in range(self.policy_iterations):

            with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
                # TODO: Use the advantages and calculated policies to calculated the clipping function here and calculate
                #  the loss function
                # ratio = tf.exp(policy_probabilities(self.actor.predict(states)[0], actions) - logprobs)
                ratio = tf.exp(policy_probabilities(agent.actor(states), actions) - logprobs)
                #print(f'values: {type(self.critic(states))}, {len(self.critic(states))}, {self.critic(states)}')
                #print(f'G_lams2: {type(G_lams)}, {len(G_lams)}, {G_lams}')
                #advantages = tf.subtract(G_lams, agent.critic(states))
                ##advantages = tf.math.subtract(G_lams, 0.05)
                #advantages returns a x*x tensor, but should return a x*0 tensor ???
                ##advantages = list(map(lambda x, y: x - y, G_lams, tf.dtypes.cast(values_global, tf.float32)))
                print(f'ratio: {type(ratio)}, {len(ratio)}, {ratio}')
                #print(f'advantages2: {type(advantages)}, {len(advantages)}, {advantages}')
                clip = keras.backend.clip(ratio, min_value=1 - self.clip_ratio, max_value=1 + self.clip_ratio) * advantages
                print(f'clip: {type(clip)}, {len(clip)}, {clip}')
                pol_loss = -keras.backend.mean(tf.minimum(ratio * advantages, clip))

            pol_grads = tape.gradient(pol_loss, agent.actor.trainable_variables)
            agent.actor_optimizer.apply_gradients(zip(pol_grads, agent.actor.trainable_variables))
            #self.actor.apply_gradients(zip(pol_grads, self.actor.trainable_variables))

    # This is a wrapper that when adding it in front of a function, consisting only of tf syntax,
    # can improve speed
    @tf.function
    def update_value_parameters(self, G_lams, states):

        for _ in range(self.value_iterations):

            with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
                # TODO: Use the advantages and calculated policies to calculated the clipping function here and calculate
                #  the loss function
                #val_loss = tf.keras.metrics.mean_squared_error(G_lams, values_global)
                val_loss = tf.keras.metrics.mean_squared_error(G_lams, agent.critic(states))
            #print(f'len_G: {len(G_lams)}, len_values: {len(values_global)} ')
            #print(f'len_G: {len(G_lams)}') #Problem: length of G_lam is 0 or all lengths are different
            #print(f'values_global: {type(values_global)}, {values_global}')
            #print(f'val_loss: {val_loss}')
            val_grads = tape.gradient(val_loss, agent.critic.trainable_variables)
            #print(f'val_grads: {val_grads}')
            agent.critic_optimizer.apply_gradients(zip(val_grads, agent.critic.trainable_variables))
            #self.critic.apply_gradients(zip(val_grads, self.critic.trainable_variables))

# %%
if __name__ == "__main__":
    environment = GymEnvironment('CartPole-v0', 'gymresults/cartpole-v0')

    no_of_states = 4  # TODO: Define number of states # [position of cart, velocity of cart, angle of pole, rotation rate of pole]
    no_of_actions = 2  # TODO: Define number of actions # [left, right]

    # The agent is initialized
    agent = PPO_Agent(no_of_states, no_of_actions)

    # Train your agent
    no_episodes = 10  # TODO: Play around with this number, default: 500, testing: 10
    environment.trainPPO(agent, no_episodes)

    # Run your agent
    no_episodes_run = 10 #default: 100
    agent.actors = 1  # This is set to one here as multiple actors are only required for training
    rew = environment.runPPO(agent, no_episodes_run)

    # TODO: Implement here a function visualizing/plotting, e.g., -- NOT YET
    # your agent's performance over the number of training episodes
# Out:
# Episode 0 actor 0: reward: 10.0 /400
# Episode 0 actor 1: reward: 13.0 /400
# Episode 0 actor 2: reward: 12.0 /400
# Episode 0 actor 3: reward: 21.0 /400
# Episode 0 actor 4: reward: 11.0 /400
# Episode 0 actor 5: reward: 12.0 /400
# Episode 0 actor 6: reward: 26.0 /400
# Episode 0 actor 7: reward: 25.0 /400
# Episode 0 actor 8: reward: 41.0 /400
# Episode 0 actor 9: reward: 27.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_1:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_1:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_4:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_2:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_7:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_3:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_10:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_4:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_13:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_5:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_16:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_6:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_19:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_7:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_22:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_8:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_25:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_9:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_28:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_1:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_1:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_4:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_2:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_7:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_3:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_10:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_4:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_13:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_5:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_16:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_6:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_19:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_7:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_22:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_8:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_25:0", shape=(198,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("Exp_9:0", shape=(198,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 198, Tensor("mul_28:0", shape=(198,), dtype=float32)
# Episode 1 actor 0: reward: 27.0 /400
# Episode 1 actor 1: reward: 10.0 /400
# Episode 1 actor 2: reward: 13.0 /400
# Episode 1 actor 3: reward: 9.0 /400
# Episode 1 actor 4: reward: 11.0 /400
# Episode 1 actor 5: reward: 12.0 /400
# Episode 1 actor 6: reward: 25.0 /400
# Episode 1 actor 7: reward: 9.0 /400
# Episode 1 actor 8: reward: 12.0 /400
# Episode 1 actor 9: reward: 17.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_1:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_1:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_4:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_2:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_7:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_3:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_10:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_4:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_13:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_5:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_16:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_6:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_19:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_7:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_22:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_8:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_25:0", shape=(145,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("Exp_9:0", shape=(145,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 145, Tensor("mul_28:0", shape=(145,), dtype=float32)
# Episode 2 actor 0: reward: 9.0 /400
# Episode 2 actor 1: reward: 10.0 /400
# Episode 2 actor 2: reward: 9.0 /400
# Episode 2 actor 3: reward: 29.0 /400
# Episode 2 actor 4: reward: 8.0 /400
# Episode 2 actor 5: reward: 14.0 /400
# Episode 2 actor 6: reward: 12.0 /400
# Episode 2 actor 7: reward: 13.0 /400
# Episode 2 actor 8: reward: 12.0 /400
# Episode 2 actor 9: reward: 12.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_1:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_1:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_4:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_2:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_7:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_3:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_10:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_4:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_13:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_5:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_16:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_6:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_19:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_7:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_22:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_8:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_25:0", shape=(128,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("Exp_9:0", shape=(128,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 128, Tensor("mul_28:0", shape=(128,), dtype=float32)
# Episode 3 actor 0: reward: 12.0 /400
# Episode 3 actor 1: reward: 15.0 /400
# Episode 3 actor 2: reward: 16.0 /400
# Episode 3 actor 3: reward: 11.0 /400
# Episode 3 actor 4: reward: 11.0 /400
# Episode 3 actor 5: reward: 16.0 /400
# Episode 3 actor 6: reward: 10.0 /400
# Episode 3 actor 7: reward: 16.0 /400
# Episode 3 actor 8: reward: 15.0 /400
# Episode 3 actor 9: reward: 13.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_1:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_1:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_4:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_2:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_7:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_3:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_10:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_4:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_13:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_5:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_16:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_6:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_19:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_7:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_22:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_8:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_25:0", shape=(135,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("Exp_9:0", shape=(135,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 135, Tensor("mul_28:0", shape=(135,), dtype=float32)
# Episode 4 actor 0: reward: 10.0 /400
# Episode 4 actor 1: reward: 10.0 /400
# Episode 4 actor 2: reward: 10.0 /400
# Episode 4 actor 3: reward: 14.0 /400
# Episode 4 actor 4: reward: 11.0 /400
# Episode 4 actor 5: reward: 11.0 /400
# Episode 4 actor 6: reward: 13.0 /400
# Episode 4 actor 7: reward: 14.0 /400
# Episode 4 actor 8: reward: 11.0 /400
# Episode 4 actor 9: reward: 18.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_1:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_1:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_4:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_2:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_7:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_3:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_10:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_4:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_13:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_5:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_16:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_6:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_19:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_7:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_22:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_8:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_25:0", shape=(122,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("Exp_9:0", shape=(122,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 122, Tensor("mul_28:0", shape=(122,), dtype=float32)
# Episode 5 actor 0: reward: 11.0 /400
# Episode 5 actor 1: reward: 11.0 /400
# Episode 5 actor 2: reward: 15.0 /400
# Episode 5 actor 3: reward: 12.0 /400
# Episode 5 actor 4: reward: 10.0 /400
# Episode 5 actor 5: reward: 17.0 /400
# Episode 5 actor 6: reward: 11.0 /400
# Episode 5 actor 7: reward: 17.0 /400
# Episode 5 actor 8: reward: 9.0 /400
# Episode 5 actor 9: reward: 13.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_1:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_1:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_4:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_2:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_7:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_3:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_10:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_4:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_13:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_5:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_16:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_6:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_19:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_7:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_22:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_8:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_25:0", shape=(126,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("Exp_9:0", shape=(126,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 126, Tensor("mul_28:0", shape=(126,), dtype=float32)
# Episode 6 actor 0: reward: 10.0 /400
# Episode 6 actor 1: reward: 12.0 /400
# Episode 6 actor 2: reward: 12.0 /400
# Episode 6 actor 3: reward: 12.0 /400
# Episode 6 actor 4: reward: 10.0 /400
# Episode 6 actor 5: reward: 11.0 /400
# Episode 6 actor 6: reward: 10.0 /400
# Episode 6 actor 7: reward: 10.0 /400
# Episode 6 actor 8: reward: 9.0 /400
# Episode 6 actor 9: reward: 11.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_1:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_1:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_4:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_2:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_7:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_3:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_10:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_4:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_13:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_5:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_16:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_6:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_19:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_7:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_22:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_8:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_25:0", shape=(107,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("Exp_9:0", shape=(107,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 107, Tensor("mul_28:0", shape=(107,), dtype=float32)
# Episode 7 actor 0: reward: 17.0 /400
# Episode 7 actor 1: reward: 10.0 /400
# Episode 7 actor 2: reward: 9.0 /400
# Episode 7 actor 3: reward: 12.0 /400
# Episode 7 actor 4: reward: 9.0 /400
# Episode 7 actor 5: reward: 11.0 /400
# Episode 7 actor 6: reward: 13.0 /400
# Episode 7 actor 7: reward: 9.0 /400
# Episode 7 actor 8: reward: 11.0 /400
# Episode 7 actor 9: reward: 9.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_1:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_1:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_4:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_2:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_7:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_3:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_10:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_4:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_13:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_5:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_16:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_6:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_19:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_7:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_22:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_8:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_25:0", shape=(110,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("Exp_9:0", shape=(110,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 110, Tensor("mul_28:0", shape=(110,), dtype=float32)
# Episode 8 actor 0: reward: 10.0 /400
# Episode 8 actor 1: reward: 12.0 /400
# Episode 8 actor 2: reward: 12.0 /400
# Episode 8 actor 3: reward: 16.0 /400
# Episode 8 actor 4: reward: 11.0 /400
# Episode 8 actor 5: reward: 9.0 /400
# Episode 8 actor 6: reward: 11.0 /400
# Episode 8 actor 7: reward: 10.0 /400
# Episode 8 actor 8: reward: 12.0 /400
# Episode 8 actor 9: reward: 17.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_1:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_1:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_4:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_2:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_7:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_3:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_10:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_4:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_13:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_5:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_16:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_6:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_19:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_7:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_22:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_8:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_25:0", shape=(120,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("Exp_9:0", shape=(120,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 120, Tensor("mul_28:0", shape=(120,), dtype=float32)
# Episode 9 actor 0: reward: 11.0 /400
# Episode 9 actor 1: reward: 11.0 /400
# Episode 9 actor 2: reward: 12.0 /400
# Episode 9 actor 3: reward: 10.0 /400
# Episode 9 actor 4: reward: 10.0 /400
# Episode 9 actor 5: reward: 11.0 /400
# Episode 9 actor 6: reward: 12.0 /400
# Episode 9 actor 7: reward: 10.0 /400
# Episode 9 actor 8: reward: 11.0 /400
# Episode 9 actor 9: reward: 8.0 /400
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_1:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_1:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_4:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_2:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_7:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_3:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_10:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_4:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_13:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_5:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_16:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_6:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_19:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_7:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_22:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_8:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_25:0", shape=(106,), dtype=float32)
# ratio: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("Exp_9:0", shape=(106,), dtype=float32)
# clip: <class 'tensorflow.python.framework.ops.Tensor'>, 106, Tensor("mul_28:0", shape=(106,), dtype=float32)
# total reward: 1297.0 /40000
# total reward: 120.0 /4000
